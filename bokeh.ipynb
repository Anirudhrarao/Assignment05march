# %%
# !pip install bokeh
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# Q1. How can you create a Bokeh plot using Python code?

# %%
import bokeh.io 
import bokeh.plotting 
bokeh.io.output_notebook()

# %%
from bokeh.plotting import figure, output_file, show
from bokeh.sampledata.iris import flowers

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
output_file('test.html')
p = figure(title = 'test flower')
p.xaxis.axis_label = "petal_length"
p.yaxis.axis_label = "petal_width"
p.circle(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
#   <div class="bk-root" id="18e28b47-acbd-44d7-9297-887206d6eb5a" data-root-id="1002"></div>

# %%
output_file('test.html')
p = figure(title = 'test flower')
p.xaxis.axis_label = "petal_length"
p.yaxis.axis_label = "petal_width"
p.line(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
#   <div class="bk-root" id="28f9abd1-641c-4750-83d0-82be8a9557c0" data-root-id="1472"></div>

# %%
x = [1,2,3,4,8]
y = [4,5,6,2,2]
output_file("line.html")
p = figure(title="line graph")
p.line(x,y)
show(p)
# Out:
#   <div class="bk-root" id="8e384c86-8c2a-4df6-aa23-0132c3f37669" data-root-id="1732"></div>

# %%
x = [1,2,3,4,8]
y = [4,5,6,2,2]
output_file("line.html")
p = figure(title="line graph")
p.scatter(x,y,size=30,fill_color="red",legend_label = "This is my data point")
show(p)
# Out:
#   <div class="bk-root" id="34ad8dba-ad63-4e46-9b5d-7bf69713063e" data-root-id="2872"></div>

# %% [markdown]
# Q2. What are glyphs in Bokeh, and how can you add them to a Bokeh plot? Explain with an example.
#
# Ans:  Glyphs are nothing but visual shapes that are drawn to represent the data such as circles, squares, lines, rectangles, etc.

# %%
output_file("square.html")
p = figure()
p.square([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=20, color="blue")
show(p)
# Out:
#   <div class="bk-root" id="d00f5864-65a8-47b5-97e8-0b73a6264dc6" data-root-id="3194"></div>

# %% [markdown]
# Q3. How can you customize the appearance of a Bokeh plot, including the axes, title, and legend?

# %%
from bokeh.io import curdoc
x = [1, 2, 3, 4, 5]
y = [6, 7, 6, 4, 5]
output_file("dark_minimal.html")
curdoc().theme = 'dark_minimal'
p.xaxis.axis_label = "X-axis"
p.yaxis.axis_label = "Y-axis"
p = figure(title="Dark theme")
p.line(x,y)
show(p)
# Out:
#   <div class="bk-root" id="d5b9d603-be7b-4195-ac0b-a6ddaea816ff" data-root-id="3532"></div>

# %% [markdown]
# Q4. What is a Bokeh server, and how can you use it to create interactive plots that can be updated in
# real time?

# %% [markdown]
# Ans:Bokeh server makes it easy to create interactive web applications that connect front-end UI events to running Python code. Bokeh creates high-level Python models, such as plots, ranges, axes, and glyphs, and then converts these objects to JSON to pass them to its client library, BokehJS.

# %% [markdown]
# Q5. How can you embed a Bokeh plot into a web page or dashboard using Flask or Django?
#
# Ans: We can use the bokeh library to embed the charts on the web page
